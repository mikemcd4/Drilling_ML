# %%
import pandas as pd
import os

# %%
file_to_load = "Cleaned Drilling Parameters.csv"
df = pd.read_csv(file_to_load)

# %%
df
# Out:
#                       Well Name  Bit RPM (RPM)  Bit Torque (kft_lb)  \
# 0      <<<<<<< Updated upstream            NaN                  NaN
# 1                       =======            NaN                  NaN
# 2                        Well 1          177.0                  3.0
# 3                        Well 1          221.0                  3.0
# 4                        Well 1          221.0                  1.0
# ...                         ...            ...                  ...
# 34797                    Well 5            0.0                -43.0
# 34798                    Well 5            0.0                -43.0
# 34799                    Well 5            0.0                -43.0
# 34800                    Well 5            0.0                -43.0
# 34801   >>>>>>> Stashed changes            NaN                  NaN
#
#        Depth of Cut (in)   Gamma (api)  Mechanical Specific Energy (ksi)  \
# 0                    NaN           NaN                               NaN
# 1                    NaN           NaN                               NaN
# 2                  0.061  1.211953e+02                      6.280000e+01
# 3                  0.015  1.216004e+10                      1.747549e+10
# 4                  0.013  1.098020e+02                      9.770000e+01
# ...                  ...           ...                               ...
# 34797              0.000 -3.579423e+06                      1.100000e+00
# 34798              0.000 -3.782271e+06                      1.100000e+00
# 34799              0.000 -3.926343e+06                      1.100000e+00
# 34800              0.000 -4.197949e+06                      1.100000e+00
# 34801                NaN           NaN                               NaN
#
#        On Bottom ROP (ft_per_hr)  Rotary RPM (RPM)  \
# 0                            NaN               NaN
# 1                            NaN               NaN
# 2                          53.39              8.06
# 3                          14.66             29.54
# 4                          10.12             29.62
# ...                          ...               ...
# 34797                    3582.11              0.00
# 34798                    3785.11              0.00
# 34799                    3929.29              0.00
# 34800                    4201.10              0.00
# 34801                        NaN               NaN
#
#        Total Pump Output (gal_per_min)  Weight on Bit (klbs)
# 0                                  NaN                   NaN
# 1                                  NaN                   NaN
# 2                               604.15                  56.0
# 3                               769.07                  34.3
# 4                               771.56                  14.1
# ...                                ...                   ...
# 34797                             0.00                  61.6
# 34798                             0.00                  62.3
# 34799                             0.00                  63.5
# 34800                             0.00                  63.8
# 34801                              NaN                   NaN
#
# [34802 rows x 10 columns]

# %%
from sqlalchemy import create_engine

from config import db_password

db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/Drilling"

engine = create_engine(db_string)

# %%
df.to_sql(name='wells', con=engine)

# %%
pd.read_sql('wells', con=engine)
# Out:
#        index                 Well Name  Bit RPM (RPM)  Bit Torque (kft_lb)  \
# 0          0  <<<<<<< Updated upstream            NaN                  NaN
# 1          1                   =======            NaN                  NaN
# 2          2                    Well 1          177.0                  3.0
# 3          3                    Well 1          221.0                  3.0
# 4          4                    Well 1          221.0                  1.0
# ...      ...                       ...            ...                  ...
# 34797  34797                    Well 5            0.0                -43.0
# 34798  34798                    Well 5            0.0                -43.0
# 34799  34799                    Well 5            0.0                -43.0
# 34800  34800                    Well 5            0.0                -43.0
# 34801  34801   >>>>>>> Stashed changes            NaN                  NaN
#
#        Depth of Cut (in)   Gamma (api)  Mechanical Specific Energy (ksi)  \
# 0                    NaN           NaN                               NaN
# 1                    NaN           NaN                               NaN
# 2                  0.061  1.211953e+02                      6.280000e+01
# 3                  0.015  1.216004e+10                      1.747549e+10
# 4                  0.013  1.098020e+02                      9.770000e+01
# ...                  ...           ...                               ...
# 34797              0.000 -3.579423e+06                      1.100000e+00
# 34798              0.000 -3.782271e+06                      1.100000e+00
# 34799              0.000 -3.926343e+06                      1.100000e+00
# 34800              0.000 -4.197949e+06                      1.100000e+00
# 34801                NaN           NaN                               NaN
#
#        On Bottom ROP (ft_per_hr)  Rotary RPM (RPM)  \
# 0                            NaN               NaN
# 1                            NaN               NaN
# 2                          53.39              8.06
# 3                          14.66             29.54
# 4                          10.12             29.62
# ...                          ...               ...
# 34797                    3582.11              0.00
# 34798                    3785.11              0.00
# 34799                    3929.29              0.00
# 34800                    4201.10              0.00
# 34801                        NaN               NaN
#
#        Total Pump Output (gal_per_min)  Weight on Bit (klbs)
# 0                                  NaN                   NaN
# 1                                  NaN                   NaN
# 2                               604.15                  56.0
# 3                               769.07                  34.3
# 4                               771.56                  14.1
# ...                                ...                   ...
# 34797                             0.00                  61.6
# 34798                             0.00                  62.3
# 34799                             0.00                  63.5
# 34800                             0.00                  63.8
# 34801                              NaN                   NaN
#
# [34802 rows x 11 columns]
